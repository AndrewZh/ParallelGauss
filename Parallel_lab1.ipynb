# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
data = pd.read_csv("LinearGauss/reports/2015-05-07/Nx1_4_nodes.csv")
data
# Out:
#     Size  Linear Gauss  Tiled Single  OpenMP(outer)  OpenMP(inner)  \
# 0    100      0.005875      0.008936        0.01253       0.003196
# 1    200      0.016130      0.032990        0.03251       0.014680
# 2    300      0.052990      0.077280        0.11700       0.048380
# 3    400      0.125000      0.183600        0.30130       0.123500
# 4    500      0.234300      0.381700        0.58780       0.328600
# 5    600      0.400000      0.825600        1.14000       0.675300
# 6    700      0.640800      1.589000        2.06300       1.045000
# 7    800      0.943400      2.656000        3.31500       1.609000
# 8    900      2.023000      5.457000        4.93800       2.564000
# 9   1000      2.775000      7.119000        8.25300       5.375000
# 10  1100      3.696000      8.376000       12.03000       7.528000
# 11  1200      4.706000     11.230000       16.70000       9.816000
# 12  1300      6.138000     17.450000       23.09000      14.080000
# ...

# %%
#from mpld3 import enable_notebook
#enable_notebook()

# %%
fig = figure(figsize=(15, 15))
plot(data["Size"].values, data["Linear Gauss"].values, marker = 'o', c = 'magenta', alpha = 0.6, label = "Linear")
plot(data["Size"].values, data["Tiled Single"].values, marker = '<', c = 'blue', alpha = 0.6, label = "Tiled")
plot(data["Size"].values, data["OpenMP(outer)"].values, marker = '>', c = 'yellow', alpha = 0.6, label = "Outer")
plot(data["Size"].values, data["OpenMP(inner)"].values, marker = 'p', c = 'red', alpha = 0.6, label = "Inner")
plot(data["Size"].values, data["OpenMP(single loop)"].values, marker = 'p', c = 'red', alpha = 0.6, label = "Single loop")
legend(loc = 2)

# %%
fig.savefig("LinearGauss/reports/2015-05-07/plot_Nx1_4_nodes.png")
