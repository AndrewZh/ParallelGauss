# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
data = pd.read_csv("LinearGauss/result_4_threads_100_to_3000.csv")
data
# Out:
#     Size  Linear Gauss  Tiled Single  OpenMP(outer)  OpenMP(inner)  \
# 0    100      0.005847       0.01203        0.02430        0.03775
# 1    200      0.047520       0.09727        0.04307        0.10790
# 2    300      0.128500       0.28150        0.12620        0.28300
# 3    400      0.250200       0.73790        0.38350        0.38940
# 4    500      0.516100       1.39000        0.58870        0.71390
# 5    600      0.691500       1.62700        1.02500        0.94920
# 6    700      0.636400       1.28900        0.65490        0.76150
# 7    800      0.943000       1.92900        0.93130        1.03200
# 8    900      1.340000       2.75000        1.31300        1.52700
# 9   1000      1.843000       3.78400        1.65900        2.46600
# 10  1100      6.835000      14.99000        4.10300        3.12300
# 11  1200      3.181000       6.53700        3.96600        4.80200
# 12  1300     11.780000      24.34000        5.89700        4.03000
# 13  1400     14.480000      29.75000        6.31500        5.72000
# 14  1500     18.910000      35.87000        7.29200        6.75200
# 15  1600     22.050000      43.52000        8.91200        9.91800
# 16  1700     26.060000      51.66000        9.67500       12.45000
# 17  1800     29.480000      61.81000       12.33000       14.86000
# 18  1900     36.750000      77.13000       13.17000       14.94000
# 19  2000     44.520000      87.68000       15.35000       21.33000
# 20  2100     18.150000      36.19000       21.17000       22.98000
# 21  2200     57.360000     119.80000       20.44000       26.84000
# 22  2300     22.390000      46.50000       21.02000       24.62000
# 23  2400     26.530000      52.57000       31.69000       33.66000
# 24  2500     28.940000      59.42000       34.86000       39.51000
# 25  2600     32.330000      67.03000       41.51000       43.00000
# 26  2700     37.390000      74.73000       45.21000       48.19000
# 27  2800     41.700000      88.90000       51.29000       54.00000
# 28  2900     47.050000     103.70000       57.46000       59.00000
# 29  3000     50.400000     107.80000       62.54000       64.84000
#
#     OpenMP(single loop)
# 0                0.0681
# 1                0.3705
# 2                0.4551
# 3                0.7360
# 4                1.1190
# 5                1.5650
# 6                1.8730
# 7                2.5920
# 8                3.4350
# 9                9.5200
# 10               7.2190
# 11              14.1400
# 12              15.2200
# 13              20.4500
# 14              25.9500
# 15              34.7900
# 16              41.0800
# 17              49.7800
# 18              55.5600
# 19              66.0300
# 20              79.1700
# 21              90.8400
# 22              93.6700
# 23             118.7000
# 24             127.5000
# 25             152.0000
# 26             175.1000
# 27             204.8000
# 28             209.2000
# 29             243.9000

# %%
#from mpld3 import enable_notebook
#enable_notebook()

# %%
fig = figure(figsize=(15, 15))
plot(data["Size"].values, data["Linear Gauss"].values, marker = 'o', c = 'magenta', alpha = 0.6, label = "Linear")
plot(data["Size"].values, data["Tiled Single"].values, marker = '<', c = 'blue', alpha = 0.6, label = "Tiled")
plot(data["Size"].values, data["OpenMP(outer)"].values, marker = '>', c = 'yellow', alpha = 0.6, label = "Outer")
plot(data["Size"].values, data["OpenMP(inner)"].values, marker = 'p', c = 'red', alpha = 0.6, label = "Inner")
plot(data["Size"].values, data["OpenMP(single loop)"].values, marker = 'p', c = 'red', alpha = 0.6, label = "Single loop")
legend(loc = 2)

# %%
fig.savefig("plot_results_4_threads_100_to_3000.png")
